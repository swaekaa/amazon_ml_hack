# %%
import numpy as np
import pandas as pd
import joblib

# %%
test_csv_path = r"C:\Users\Ekaansh\OneDrive\Desktop\AB\vs code\JS\projects\hackathon\amazon\data\test_processed.csv"
embedding_path = r"C:\Users\Ekaansh\OneDrive\Desktop\AB\vs code\JS\projects\hackathon\amazon\models\with image\test_cnn_features_efficientnetb3.npy"

cat_model_path = r"C:\Users\Ekaansh\OneDrive\Desktop\AB\vs code\JS\projects\hackathon\amazon\models\with image\CatBoost_model_gpu.pkl"
lgb_model_path = r"C:\Users\Ekaansh\OneDrive\Desktop\AB\vs code\JS\projects\hackathon\amazon\models\with image\LightGBM_model_gpu.pkl"
xgb_model_path = r"C:\Users\Ekaansh\OneDrive\Desktop\AB\vs code\JS\projects\hackathon\amazon\models\with image\XGBoost_model_gpu.pkl"

weights = {"CatBoost": 0.2, "LightGBM": 0.4, "XGBoost": 0.4}

# %%
test_df = pd.read_csv(test_csv_path)
test_embeddings = np.load(embedding_path)  # shape: (n_samples, 1536)
print(f"✅ Loaded embeddings shape: {test_embeddings.shape}")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 test_df = pd.read_csv(test_csv_path)
# ----> 2 test_embeddings = np.load(embedding_path)  # shape: (n_samples, 1536)
#       3 print(f"✅ Loaded embeddings shape: {test_embeddings.shape}")
#
# File c:\Users\Ekaansh\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\npyio.py:456, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453         return format.open_memmap(file, mode=mmap_mode,
#     454                                   max_header_size=max_header_size)
#     455     else:
# --> 456         return format.read_array(fid, allow_pickle=allow_pickle,
#     457                                  pickle_kwargs=pickle_kwargs,
#     458                                  max_header_size=max_header_size)
#     459 else:
#     460     # Try a pickle
#     461     if not allow_pickle:
#
# File c:\Users\Ekaansh\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\format.py:809, in read_array(fp, allow_pickle, pickle_kwargs, max_header_size)
#     806 else:
#     807     if isfileobj(fp):
#     808         # We can use the fast fromfile() function.
# --> 809         array = numpy.fromfile(fp, dtype=dtype, count=count)
#     810     else:
#     811         # This is not a real file. We have to read it the
#     812         # memory-intensive way.
#    (...)    820         # not correctly instantiate zero-width string dtypes; see
#     821         # https://github.com/numpy/numpy/pull/6430
#     822         array = numpy.ndarray(count, dtype=dtype)
#
# MemoryError: Unable to allocate 439. MiB for an array with shape (115200000,) and data type float32
